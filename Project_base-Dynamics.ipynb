# %%
import Pkg
Pkg.activate(@__DIR__)
Pkg.instantiate()
import MathOptInterface as MOI
import Ipopt 
import FiniteDiff
import ForwardDiff
import Convex as cvx 
import ECOS
using LinearAlgebra
using Plots
using Random
using JLD2
using Test
import MeshCat as mc 
using Statistics
# Out:
#   Activating environment at `C:\Users\sriku\Downloads\OCRL Project\OCRL Project\Project.toml`
#    Installed OrderedCollections ─ v1.5.0
#    Installed ArrayInterface ───── v7.4.1
# Precompiling project...
#   ✓ OrderedCollections
#   ✓ ArrayInterface
#   ✓ Parameters
#   ✓ Tables
#   ✓ Widgets
#   ✓ FiniteDiff
#   ✓ Mustache
#   ✓ StructArrays
#   ✓ DataStructures
#   ✓ Latexify
#   ✓ SortingAlgorithms
#   ✓ WebIO
#   ✓ StatsBase
#   ✓ JSExpr
#   ✓ GeometryBasics
#   ✓ Blink
#   ✓ JLD2
#   ✓ MeshCat
#   ✓ MathOptInterface
#   ✓ ECOS
#   ✓ Convex
#   ✓ Plots
#   ✓ Ipopt
#   23 dependencies successfully precompiled in 99 seconds (172 already precompiled)

# %%
include(joinpath(@__DIR__, "utils","fmincon.jl"))
include(joinpath(@__DIR__, "utils","planar_vehicle.jl"))
# Out:
# check_dynamic_feasibility (generic function with 1 method)

# %% [markdown]
# <!-- function dynamics(params,X, u)
#
#
#     # params :L (distance between front and rear axis)
#     # X :[x,y,theta]
#     # U : [v,delta]
#
#
#     s= sin(X[3])
#     c = cos(X[3])
#
#     xd = U[1]*c# vcos(theta)
#     yd = U[1]*s # vsin(theta)
#     thetad = U[1]*tan(U[2])/params.L # v*tan(δ)/L
#
#     dX = [xd;yd;thetad]
#     return [X;dX]
#
# end -->
#
#
#
# $$\begin{align} x = \begin{bmatrix} p_x \\ p_y \\ \theta \\ \delta \\ v \end{bmatrix}, &\quad \quad u = \begin{bmatrix} a \\ \dot{\delta} \end{bmatrix}  \end{align} $$
#
# where $p_x$ and $p_y$ describe the 2d position of the bike, $\theta$ is the orientation, $\delta$ is the steering angle, and $v$ is the velocity. The controls for the bike are acceleration $a$, and steering angle rate $\dot{\delta}$.

# %%
function single_car_dynamics(params::NamedTuple, x::Vector, u::Vector)::Vector
    # nonlinear bicycle model continuous time dynamics 
    px, py, θ, δ, v = x 
    a, δdot = u 
    
    β = atan(params.lr * δ, params.L)
    s,c = sincos(θ + β)
    ω = v*cos(β)*tan(δ) / params.L
    
    vx = v*c 
    vy = v*s 
    
    xdot = [
        vx,
        vy,
        ω,
        δdot, 
        a
    ]
    
    return xdot
end

function combined_dynamics(params, x,u)
    
    # car 1 
    x1 = x[1:5]
    u1 = u[1:2]
    xdot1 = single_car_dynamics(params, x1, u1)
    
    # car 2
    x2 = x[(1:5) .+ 5]
    u2 = u[(1:2) .+ 2]
    xdot2 = single_car_dynamics(params, x2, u2)
    
    return [xdot1;xdot2]
end

function hermite_simpson(params::NamedTuple, x1::Vector, x2::Vector, u, dt::Real)::Vector
    # TODO: input hermite simpson implicit integrator residual
    ẋ1 = combined_dynamics(params, x1, u)
    ẋ2 = combined_dynamics(params, x2, u)
    xh = 0.5*(x1+x2) + (dt/8)*(ẋ1-ẋ2)
    ẋh = combined_dynamics(params,xh,u)
    
    return ẋh - ((-3/(2*dt))*(x1-x2) - 0.25*(ẋ1+ẋ2))

end
# Out:
# hermite_simpson (generic function with 1 method)

# %%
function create_idx(nx,nu,N)
    # This function creates some useful indexing tools for Z 
    # x_i = Z[idx.x[i]]
    # u_i = Z[idx.u[i]]
    
    # Feel free to use/not use anything here.
    
    
    # our Z vector is [x0, u0, x1, u1, …, xN]
    nz = (N-1) * nu + N * nx # length of Z 
    x = [(i - 1) * (nx + nu) .+ (1 : nx) for i = 1:N]
    u = [(i - 1) * (nx + nu) .+ ((nx + 1):(nx + nu)) for i = 1:(N - 1)]
    
    # constraint indexing for the (N-1) dynamics constraints when stacked up
    c = [(i - 1) * (nx) .+ (1 : nx) for i = 1:(N - 1)]
    nc = (N - 1) * nx # (N-1)*nx 
    
    return (nx=nx,nu=nu,N=N,nz=nz,nc=nc,x= x,u = u,c = c)
end

function vehicle_cost(params::NamedTuple, Z::Vector)::Real
    idx, N, xref1, xref2 = params.idx, params.N, params.xref1, params.xref2
    Q, R1, R2, Qf = params.Q, params.R1, params.R2, params.Qf
    
    # TODO: input cartpole LQR cost 
#     println("started")
    J = 0 
    for i = 1:(N-1)
        xi = Z[idx.x[i]]
        ui = Z[idx.u[i]] 
        J += 0.5*(xi[1:5] - xref1[i])'*Q*(xi[1:5] - xref1[i]) + 0.5*ui[1:2]'*R1*ui[1:2]
        J += 0.5*(xi[6:10] - xref2[i])'*Q*(xi[6:10] - xref2[i]) + 0.5*ui[3:4]'*R2*ui[3:4]
    end
    xn = Z[idx.x[N]]
    J += 0.5 * (xn[1:5]-xref1[N])'*Qf*(xn[1:5]-xref1[N])
    J += 0.5 * (xn[6:10]-xref2[N])'*Qf*(xn[6:10]-xref2[N])
  
    return J 
end

function vehicle_dynamics_constraints(params::NamedTuple, Z::Vector)::Vector
    idx, N, dt = params.idx, params.N, params.dt
    
    # TODO: create dynamics constraints using hermite simpson 
    
    c = zeros(eltype(Z), idx.nc)
    
    for i = 1:(N-1)
        xi = Z[idx.x[i]]
        ui = Z[idx.u[i]] 
        xip1 = Z[idx.x[i+1]]
        
        # TODO: hermite simpson 
        c[idx.c[i]] = hermite_simpson(params, xi, xip1, ui, dt)
            
    end
    
    return c 
end

function vehicle_equality_constraint(params::NamedTuple, Z::Vector)::Vector
    N, idx = params.N, params.idx
    x1ic, x2ic = params.x1ic, params.x2ic

    dym_c = vehicle_dynamics_constraints(params,Z)
    eq_c = [[x1ic;x2ic]-Z[idx.x[1]]; dym_c]
    return eq_c 
end

function inequality_constraint(params::NamedTuple, Z::Vector)

    N, idx, xref1, xref2 = params.N, params.idx, params.xref1, params.xref2
    # one for distance between two cars, two for the upper and lower bounds of road
    
    ineq_c = zeros(eltype(Z),N+1)
    for i = 1:N-1
        x = Z[idx.x[i]]
        pos1 = x[1:2]
        pos2 = x[6:7]
        dist = norm(pos1-pos2)^2
        ineq_c[i] = dist
    end
    xn = Z[idx.x[N]]
    pos1 = xn[1:2]
    pos2 = xn[6:7]
    xrefn1 = xref1[N][1:2]
    xrefn2 = xref2[N][1:2]
    ineq_c[end-1:end] = [norm(pos1-xrefn1)^2;norm(pos2-xrefn2)^2]
    return ineq_c
end

"""
    vehicle_path

Function for returning collision free trajectories for 2 cars. 

Outputs:
    x1::Vector{Vector}  # state trajectory for car 1 
    x2::Vector{Vector}  # state trajectory for car 2 
    u1::Vector{Vector}  # control trajectory for car 1 
    u2::Vector{Vector}  # control trajectory for car 2 
    t_vec::Vector
    params::NamedTuple

The resulting trajectories should have dt=0.2, tf = 50, N = 100

"""
function vehicle_path(;verbose=true)
    
    # problem size 
    nx = 10
    nu = 4
    dt = 0.5
    tf = 12
    t_vec = 0:dt:tf 
    N = length(t_vec)
    L = 2.8
    lr = 1.6
    
    # indexing 
    idx = create_idx(nx,nu,N)
    
    # initial conditions and goal states 
    x1ic = [0,-1.5,0,0,0] # ic for quad 1 
    x2ic = [10,-1.5,0,0,0] # ic for quad 2 
    
    ### Reference Trajectories
    x1 = range(1, stop=150, length=N);
    y1 = -1.5*ones(N);
    theta1 = zeros(N);
    δ1 = zeros(N);
    v1 = 13*ones(N);
    A1 = hcat(x1,y1,theta1,δ1,v1)
    xref1 = [A1[i,:] for i in 1:size(A1,1)]

    x2 = range(10, stop=130, length=N);
    y2 = -1.5*ones(N);
    theta2 = zeros(N);
    δ2 = zeros(N);
    v2 = 10*ones(N)
    A2 = hcat(x2,y2,theta2,δ2,v2)
    xref2 = [A2[i,:] for i in 1:size(A2,1)]
    
#     Q1 = diagm(ones(3))
#     Q2 = 10*diagm(ones(3))   
#     R1 = 0.5*diagm(ones(2))
#     R2 = 1*diagm(ones(2))    
#     Qf = 10*diagm(ones(3))
    Q = diagm([10,10,10,0.01,0.01])
    Qf = diagm([10,10,10,0.01,0.01])
    R1 = diagm([1,5])
    R2 = diagm([10,10])
    
    
    # load all useful things into params 
    # TODO: include anything you would need for a cost function (like a Q, R, Qf if you were doing an 
    # LQR cost)
    params = (x1ic=x1ic,
              x2ic=x2ic,
              xic = [x1ic;x2ic],
              xref1 = xref1,
              xref2 = xref2,
              dt = dt,
              N = N,
              idx = idx,
              Q = Q,
              R1 = R1,
              R2 = R2,
              Qf = Qf,
               L = L,
              lr = lr)    
    
    ### Primal Bounds
    ### inf bound for angular velocity and steering rate
    x_l = [[-Inf, -2,-pi/5,-pi/8, 0, -Inf, -1.5,-pi/5,-pi/8, 0, -4, -5, -4, -5] for i = 1:N-1]
    x_l = reduce(vcat,x_l)
    x_l = [x_l;[-Inf, -2.5,-pi/5,-pi/8, 0, -Inf, -2.5,-pi/5,-pi/8, 0]]
    x_u = [[Inf, 3,pi/5,pi/8, 20, Inf, -1.5,pi/5,pi/8, 20, 4, 5, 4, 5] for i = 1:N-1]
    x_u = reduce(vcat,x_u)
    x_u = [x_u;[Inf, 3,pi/5,pi/8, 20, Inf, 2.5,pi/5,pi/8, 20]]
    
    # Assume each car is 2 meters wide and 2.5 meters long
    c_l = 12*ones(N+1)
    c_l[end-1:end] .= 0
    c_u = Inf*ones(N+1)
    c_u[end-1:end] .= 3 
    
    ## initial guess
    z0 = 0.01*randn(idx.nz)
    diff_type = :auto

    
    Z = fmincon(vehicle_cost,vehicle_equality_constraint,inequality_constraint,
            x_l,x_u,c_l,c_u,z0,params, diff_type;
            tol = 1e-6, c_tol = 1e-6, max_iters = 10_000, verbose = verbose)
    
    x1 = [Z[idx.x[i]][1:5]  for i = 1:N]
    x2 = [Z[idx.x[i]][6:10]  for i = 1:N]
    u1 = [Z[idx.u[i]][1:2]  for i = 1:(N-1)]
    u2 = [Z[idx.u[i]][3:4]  for i = 1:(N-1)]
        
    return x1, x2, u1, u2, t_vec, params 
end
# Out:
# vehicle_path

# %%
X1, X2, U1, U2, t_vec, params  = vehicle_path(verbose=true)
    

distances = [distance_between_cars(x1[1:2],x2[1:2]) for (x1,x2) in zip(X1,X2)]
display(plot(t_vec,reduce(vcat, distances),xlabel = "time", title = "Distance between two cars"))

        
X1m = hcat(X1...)
X2m = hcat(X2...)
    
plot(X1m[1,:], X1m[2,:], color = :blue,title = "Vehicle Trajectories", label = "car 1", ylims = [-3.5,3.5])
plot!(X2m[1,:], X2m[2,:], color = :green, label = "car 2",xlabel = "p_x (m)", ylabel = "p_y (m)", legend=:topright)
plot!(3*ones(150),ls = :dash, color = :red, label = "upper road bound")
plot!(zeros(150), color = :red, label = "center of road")
display(plot!(-3*ones(150),ls = :dash, color = :red, label = "lower road bound"))
        
plot(t_vec, X1m[3,:], color = :red,title = "Car Orientations", label = "car 1")
display(plot!(t_vec, X2m[3,:], color = :green, label = "car 2",xlabel = "time (s)", ylabel = "θ"))
    
plot(t_vec, X1m[4,:], color = :red,title = "Steering Angle", label = "car 1")
display(plot!(t_vec, X2m[4,:], color = :green, label = "car 2",xlabel = "time (s)", ylabel = " δ"))
    
plot(t_vec, X1m[5,:], color = :red,title = "Velocity", label = "car 1")
display(plot!(t_vec, X2m[5,:], color = :green, label = "car 2",xlabel = "time (s)", ylabel = " velocity m/s"))
    
plot(t_vec[1:end-1],reduce(hcat,U1)'[:,1], color = :red,title = "Control Usage", label = "accel 1")
plot!(t_vec[1:end-1],reduce(hcat,U1)'[:,2], color = :pink,title = "Control Usage", label = "δ 1")
plot!(t_vec[1:end-1],reduce(hcat,U2)'[:,1], color = :blue,title = "Control Usage", label = "accel 2")
display(plot!(t_vec[1:end-1],reduce(hcat,U2)'[:,2], color = :green, label = "δ 2",xlabel = "time (s)", ylabel = "Controls"))
    
plot(t_vec, X1m[1,:], color = :red,label = "car 1")
display(plot!(t_vec, X2m[1,:], color = :green,title = "X Position vs Time", xlabel = "time", ylabel="x position", label = "car 2"))
plot(t_vec, X1m[2,:], color = :red,label = "car 1")
display(plot!(t_vec, X2m[2,:], color = :green,title = "Y Position vs Time", xlabel = "time", ylabel="Y position", label = "car 2"))
# Out:
# ---------checking dimensions of everything----------
# ---------all dimensions good------------------------
# ---------diff type set to :auto (ForwardDiff.jl)----
# ---------testing objective gradient-----------------
# ---------testing constraint Jacobian----------------
# ---------successfully compiled both derivatives-----
# ---------IPOPT beginning solve----------------------
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.4, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:    80500
# Number of nonzeros in inequality constraint Jacobian.:     8372
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:      322
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      272
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      250
# Total number of inequality constraints...............:       26
#         inequality constraints with only lower bounds:       24
#    inequality constraints with lower and upper bounds:        2
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.7384797e+06 2.25e+04 1.00e+02   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.7241370e+06 2.23e+04 3.92e+02   1.1 7.51e+01    -  3.03e-01 8.17e-03f  1
#    2  1.7239019e+06 2.23e+04 1.36e+03  -5.1 3.19e+02    -  2.60e-03 1.34e-04f  1
#    3r 1.7239019e+06 2.23e+04 1.00e+03   3.9 0.00e+00    -  0.00e+00 4.76e-07R  3
#    4r 7.2956221e+05 1.07e+04 9.99e+02   2.0 3.65e+05    -  3.78e-03 1.33e-02f  1
#    5  6.9916263e+05 1.03e+04 1.81e+03   0.8 7.67e+01    -  2.03e-05 3.72e-02f  1
#    6  6.3750867e+05 9.62e+03 1.69e+03  -0.1 7.52e+01    -  2.44e-02 6.61e-02f  1
#    7  5.9887754e+05 9.07e+03 1.59e+03   1.4 7.93e+01    -  1.13e-02 5.86e-02f  1
#    8  5.2604653e+05 8.42e+03 1.48e+03   0.0 6.93e+01    -  5.58e-02 7.28e-02f  1
#    9  4.7053980e+05 7.79e+03 1.36e+03   1.1 6.44e+01    -  1.40e-01 7.65e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.8658812e+05 6.83e+03 1.19e+03  -5.3 6.04e+01    -  6.01e-02 1.27e-01f  1
#   11  3.1641599e+05 5.96e+03 1.03e+03   0.9 5.41e+01    -  6.80e-02 1.32e-01f  1
#   12  2.4171069e+05 4.93e+03 1.04e+03   0.6 4.80e+01    -  1.15e-01 1.81e-01f  1
#   13  2.0378326e+05 4.33e+03 2.49e+03   0.9 7.11e+01    -  2.03e-01 1.26e-01f  1
#   14  1.5956474e+05 3.54e+03 5.89e+03   1.2 7.64e+01    -  2.17e-01 1.92e-01f  1
#   15  1.2191024e+05 2.83e+03 3.46e+03   0.9 8.27e+01    -  2.51e-01 2.10e-01f  1
#   16  8.6892419e+04 2.11e+03 8.09e+03   0.9 8.63e+01    -  3.12e-01 2.72e-01f  1
#   17  6.9904621e+04 1.72e+03 1.23e+04   1.1 1.22e+02    -  5.33e-01 1.94e-01f  1
#   18  3.8070932e+04 8.42e+02 2.60e+04   0.7 8.88e+01    -  2.45e-01 6.02e-01f  1
#   19  2.6551881e+04 3.50e+02 6.13e+03   0.9 8.58e+01    -  3.94e-01 7.11e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  2.3098364e+04 9.18e+01 1.40e+04   1.2 1.67e+02    -  5.11e-01 9.69e-01f  1
#   21  2.2393164e+04 2.46e+01 1.41e+03   1.3 1.34e+02    -  1.00e+00 9.61e-01f  1
#   22  2.2237159e+04 5.38e+00 2.10e+02   0.9 2.74e+01    -  1.00e+00 1.00e+00h  1
#   23  2.0752639e+04 1.38e-01 5.82e+02   0.4 9.63e+01    -  9.90e-01 1.00e+00f  1
#   24  1.9986786e+04 6.28e-01 1.60e+02   0.3 5.87e+01    -  9.98e-01 9.64e-01f  1
#   25  1.9877086e+04 3.23e-01 6.87e+01   0.3 1.57e+01    -  1.00e+00 1.00e+00f  1
#   26  1.9670834e+04 1.55e-02 3.84e+01  -0.5 3.08e+01    -  9.97e-01 1.00e+00f  1
#   27  1.9455730e+04 1.16e-01 8.02e+01  -0.9 3.02e+01    -  9.98e-01 7.01e-01f  1
#   28  1.9390457e+04 2.01e-01 3.91e+01  -0.6 3.26e+01    -  1.00e+00 1.00e+00f  1
#   29  1.9441760e+04 1.36e-01 1.40e+01  -0.4 1.20e+01    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  1.9493755e+04 2.41e-01 2.08e+02  -0.4 2.02e+01    -  7.28e-01 1.00e+00h  1
#   31  1.9399735e+04 5.63e-02 8.36e+00  -0.9 9.85e+00    -  1.00e+00 1.00e+00f  1
#   32  1.9381122e+04 8.63e-02 1.75e+01  -1.4 3.13e+00    -  9.95e-01 1.00e+00h  1
#   33  1.9364357e+04 4.73e-02 7.63e+00  -1.5 2.58e+00    -  1.00e+00 1.00e+00h  1
#   34  1.9384774e+04 1.57e-03 3.23e+00  -2.3 1.49e+00    -  1.00e+00 1.00e+00h  1
#   35  1.9378787e+04 8.89e-03 1.26e+01  -2.8 5.06e+00    -  1.00e+00 3.16e-01f  1
#   36  1.9375482e+04 9.96e-03 1.58e+01  -2.5 3.47e+00    -  1.00e+00 1.99e-01f  1
#   37  1.9372599e+04 6.89e-03 6.86e+00  -2.7 4.14e+00    -  1.00e+00 3.80e-01h  1
#   38  1.9370155e+04 1.34e-02 1.28e+01  -3.1 3.33e+00    -  1.00e+00 9.84e-01h  1
#   39  1.9360719e+04 8.21e-03 2.61e+00  -3.2 1.90e+00    -  3.35e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  1.9371164e+04 1.12e-03 2.96e+00  -3.7 4.15e-01    -  1.00e+00 1.00e+00h  1
#   41  1.9371426e+04 3.86e-04 4.05e-01  -4.9 1.74e-01    -  1.00e+00 1.00e+00h  1
#   42  1.9371633e+04 1.33e-04 1.49e+00  -6.4 2.10e-01    -  1.00e+00 9.09e-01h  1
#   43  1.9371313e+04 8.12e-04 1.99e+01  -4.8 1.29e+00    -  1.00e+00 4.83e-01h  1
#   44  1.9371066e+04 1.01e-03 1.91e+01  -4.9 1.02e+01    -  7.78e-03 4.67e-02h  1
#   45  1.9370848e+04 1.06e-03 4.62e+00  -5.7 1.15e+00    -  1.00e+00 7.29e-01h  1
#   46  1.9370457e+04 7.41e-04 1.90e+00  -4.1 6.41e-01    -  1.00e+00 1.00e+00h  1
#   47  1.9370048e+04 1.50e-03 3.68e+00  -4.7 8.78e-01    -  1.00e+00 6.43e-01h  1
#   48  1.9369812e+04 9.32e-04 8.80e-01  -4.0 3.22e-01    -  1.00e+00 1.00e+00h  1
#   49  1.9370449e+04 2.04e-04 2.10e+00  -4.7 1.29e-01    -  1.00e+00 7.86e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  1.9370645e+04 4.11e-05 8.36e-01  -5.5 3.13e-01    -  1.00e+00 9.45e-01h  1
#   51  1.9370576e+04 1.35e-04 2.06e+01  -6.3 3.57e+00    -  1.00e+00 1.51e-01h  1
#   52  1.9370543e+04 1.25e-04 3.31e+01  -6.2 2.25e+00    -  1.00e+00 8.67e-02h  1
#   53  1.9370430e+04 2.71e-03 1.89e+01  -6.2 4.10e+00    -  1.00e+00 4.78e-01f  1
#   54  1.9369830e+04 2.06e-03 1.71e+01  -6.2 5.91e-01    -  1.62e-02 1.00e+00h  1
#   55  1.9369466e+04 1.95e-03 1.34e+01  -6.2 1.06e+00    -  7.49e-01 1.00e+00h  1
#   56  1.9370247e+04 5.29e-04 3.11e+00  -5.3 4.61e-01    -  1.00e+00 1.00e+00h  1
#   57  1.9369860e+04 5.27e-04 1.90e+01  -5.4 1.24e-01    -  1.67e-01 1.00e+00h  1
#   58  1.9370499e+04 3.82e-05 2.97e-01  -5.5 1.95e-01    -  1.00e+00 9.99e-01h  1
#   59  1.9370518e+04 1.45e-05 2.01e-01  -6.3 7.06e-02    -  1.00e+00 9.93e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  1.9370516e+04 1.24e-05 2.06e-01  -7.5 5.41e-02    -  1.00e+00 1.00e+00h  1
#   61  1.9370514e+04 9.21e-06 1.33e-01  -6.9 2.95e-02    -  1.00e+00 1.00e+00h  1
#   62  1.9370519e+04 7.34e-07 8.18e-02  -8.1 7.34e-03    -  1.00e+00 1.00e+00h  1
#   63  1.9370519e+04 5.07e-07 2.08e-02  -9.3 1.45e-02    -  1.00e+00 1.00e+00h  1
#   64  1.9370519e+04 8.11e-06 5.43e-02 -10.6 4.98e-02    -  1.00e+00 1.00e+00h  1
#   65  1.9370518e+04 6.39e-05 3.22e-01 -11.0 1.26e-01    -  1.00e+00 1.00e+00h  1
#   66  1.9370508e+04 2.13e-05 3.20e+02 -11.0 5.24e-02    -  4.31e-01 1.00e+00h  1
#   67  1.9370518e+04 4.89e-08 1.36e-01 -11.0 1.09e-01    -  1.00e+00 1.00e+00H  1
#   68  1.9370515e+04 1.08e-05 3.00e-01 -11.0 4.31e-02    -  1.00e+00 1.00e+00h  1
#   69  1.9370510e+04 8.41e-06 2.60e-02 -11.0 4.61e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  1.9370518e+04 5.22e-07 6.18e-02 -11.0 5.88e-03    -  1.00e+00 1.00e+00h  1
#   71  1.9370518e+04 2.08e-07 2.42e-03 -11.0 1.15e-03    -  1.00e+00 1.00e+00h  1
#   72  1.9370518e+04 1.00e-08 2.87e-03 -11.0 2.25e-03    -  1.00e+00 1.00e+00h  1
#   73  1.9370517e+04 8.44e-07 7.71e-02 -11.0 5.76e-02    -  1.00e+00 1.00e+00h  1
#   74  1.9370517e+04 4.10e-06 1.65e-01 -11.0 1.40e-01    -  1.00e+00 1.00e+00h  1
#   75  1.9370514e+04 2.66e-05 1.82e+02 -11.0 3.56e-02    -  6.76e-01 1.00e+00h  1
#   76  1.9370506e+04 1.43e-05 4.00e-02 -11.0 1.01e-01    -  1.00e+00 1.00e+00h  1
#   77  1.9370517e+04 2.16e-07 4.06e-02 -11.0 1.06e-02    -  1.00e+00 1.00e+00h  1
#   78  1.9370517e+04 1.16e-07 5.99e-03 -11.0 1.44e-03    -  1.00e+00 1.00e+00h  1
#   79  1.9370517e+04 1.01e-08 5.14e-03 -11.0 1.77e-03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  1.9370517e+04 1.86e-07 7.38e-03 -11.0 5.73e-03    -  1.00e+00 1.00e+00h  1
#   81  1.9370521e+04 3.96e-08 6.84e+02 -11.0 6.65e-02    -  3.92e-01 1.00e+00H  1
#   82  1.9370514e+04 1.43e-05 6.33e-02 -11.0 5.08e-02    -  1.00e+00 1.00e+00h  1
#   83  1.9370522e+04 1.00e-08 3.00e-01 -11.0 6.27e-02    -  1.00e+00 1.00e+00H  1
#   84  1.9370513e+04 1.24e-05 1.22e-01 -11.0 4.11e-02    -  1.00e+00 1.00e+00f  1
#   85  1.9370512e+04 3.76e-05 3.00e+02 -11.0 8.39e-02    -  4.67e-01 1.00e+00h  1
#   86  1.9370505e+04 2.92e-05 3.03e-02 -11.0 7.30e-02    -  1.00e+00 1.00e+00h  1
#   87  1.9370517e+04 1.97e-07 5.30e-02 -11.0 1.73e-03    -  1.00e+00 1.00e+00h  1
#   88  1.9370517e+04 9.08e-08 5.01e-03 -11.0 1.24e-03    -  1.00e+00 1.00e+00h  1
#   89  1.9370517e+04 1.00e-08 1.42e-03 -11.0 1.17e-04    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  1.9370517e+04 1.00e-08 5.58e-04 -11.0 1.32e-04    -  1.00e+00 1.00e+00h  1
#   91  1.9370517e+04 1.00e-08 1.03e-03 -11.0 1.40e-03    -  1.00e+00 1.00e+00h  1
#   92  1.9370517e+04 4.53e-08 1.01e-02 -11.0 9.08e-03    -  1.00e+00 1.00e+00h  1
#   93  1.9370517e+04 4.94e-08 2.46e-02 -11.0 1.93e-03    -  1.00e+00 1.00e+00h  1
#   94  1.9370517e+04 3.23e-08 7.31e-03 -11.0 4.70e-03    -  1.00e+00 1.00e+00h  1
#   95  1.9370517e+04 1.00e-08 5.19e-03 -11.0 4.23e-04    -  1.00e+00 1.00e+00h  1
#   96  1.9370517e+04 1.00e-08 2.10e-04 -11.0 2.50e-04    -  1.00e+00 1.00e+00h  1
#   97  1.9370517e+04 1.00e-08 1.06e-04 -11.0 1.22e-04    -  1.00e+00 1.00e+00h  1
#   98  1.9370517e+04 1.00e-08 5.62e+02 -11.0 1.25e-02    -  1.00e+00 4.88e-04h 12
#   99  1.9370517e+04 1.00e-08 5.62e+02 -11.0 3.51e-03    -  1.00e+00 9.77e-04h 11
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  1.9370517e+04 1.00e-08 5.62e+02 -11.0 6.82e-03    -  1.00e+00 9.77e-04h 11
#  101  1.9370517e+04 1.00e-08 5.62e+02 -11.0 1.04e-02    -  1.00e+00 1.22e-04h 14
#  102  1.9370517e+04 1.00e-08 5.21e-03 -11.0 3.31e-03    -  1.00e+00 1.00e+00H  1
#  103  1.9370517e+04 1.00e-08 5.60e+02 -11.0 1.58e-02    -  1.00e+00 3.91e-03h  9
#  104  1.9370517e+04 1.00e-08 5.58e+02 -11.0 1.14e-03    -  1.00e+00 7.81e-03h  8
#  105  1.9370517e+04 1.00e-08 1.05e-03 -11.0 1.08e-03    -  1.00e+00 1.00e+00H  1
#  106  1.9370517e+04 1.00e-08 7.01e-03 -11.0 4.88e-04    -  1.00e+00 1.00e+00H  1
#  107  1.9370517e+04 1.00e-08 3.30e-04 -11.0 5.21e-04    -  1.00e+00 1.00e+00h  1
#  108  1.9370517e+04 1.00e-08 5.65e-04 -11.0 3.81e-05    -  1.00e+00 1.00e+00h  1
#  109  1.9370517e+04 1.00e-08 4.18e-05 -11.0 2.53e-05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  1.9370517e+04 1.00e-08 1.29e-05 -11.0 9.32e-06    -  1.00e+00 1.00e+00h  1
#  111  1.9370517e+04 1.00e-08 4.47e-04 -11.0 4.38e-04    -  1.00e+00 1.00e+00h  1
#  112  1.9370517e+04 1.00e-08 1.04e-03 -11.0 2.78e-04    -  1.00e+00 1.00e+00h  1
#  113  1.9370517e+04 1.00e-08 2.71e-04 -11.0 4.64e-04    -  1.00e+00 1.00e+00H  1
#  114  1.9370517e+04 1.00e-08 5.87e-04 -11.0 6.68e-05    -  1.00e+00 1.00e+00H  1
#  115  1.9370517e+04 1.00e-08 5.27e-05 -11.0 1.17e-04    -  1.00e+00 1.00e+00h  1
#  116  1.9370517e+04 1.00e-08 5.26e-05 -11.0 9.07e-06    -  1.00e+00 1.00e+00h  1
#  117  1.9370517e+04 1.00e-08 8.12e-06 -11.0 1.05e-05    -  1.00e+00 1.00e+00H  1
#  118  1.9370517e+04 1.00e-08 1.77e-05 -11.0 1.99e-05    -  1.00e+00 1.00e+00h  1
#  119  1.9370517e+04 1.00e-08 2.58e-04 -11.0 2.20e-04    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120  1.9370517e+04 1.00e-08 3.41e-04 -11.0 9.11e-05    -  1.00e+00 1.00e+00h  1
#  121  1.9370517e+04 1.00e-08 5.73e-04 -11.0 2.44e-04    -  1.00e+00 1.00e+00H  1
#  122  1.9370517e+04 1.00e-08 3.07e-04 -11.0 1.31e-04    -  1.00e+00 1.00e+00H  1
#  123  1.9370517e+04 1.00e-08 5.89e-04 -11.0 1.62e-04    -  1.00e+00 1.00e+00H  1
#  124  1.9370517e+04 1.00e-08 5.54e+02 -11.0 1.52e-04    -  1.00e+00 1.56e-02h  7
#  125  1.9370517e+04 1.00e-08 5.62e+02 -11.0 2.14e-04    -  1.00e+00 9.77e-04h 11
#  126  1.9370517e+04 1.00e-08 5.62e+02 -11.0 1.30e-04    -  1.00e+00 1.22e-04h 14
#  127  1.9370517e+04 1.00e-08 7.40e-04 -11.0 1.20e-04    -  1.00e+00 1.00e+00H  1
#  128  1.9370517e+04 1.00e-08 2.84e-04 -11.0 1.80e-05    -  1.00e+00 1.00e+00h  1
#  129  1.9370517e+04 1.00e-08 2.81e+02 -11.0 1.29e-05    -  1.00e+00 5.00e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130  1.9370517e+04 1.00e-08 2.81e+02 -11.0 4.33e-06    -  1.00e+00 5.00e-01h  2
#  131  1.9370517e+04 1.00e-08 6.79e-06 -11.0 1.95e-06    -  1.00e+00 1.00e+00h  1
#  132  1.9370517e+04 1.00e-08 3.03e-06 -11.0 6.09e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 132
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.2913987248194194e+03    1.9370517182244675e+04
# Dual infeasibility......:   3.0265080441204275e-06    4.5396533962842655e-05
# Constraint violation....:   9.9999996467598766e-09    9.9999996467598766e-09
# Variable bound violation:   1.9999765044076412e-07    1.9999765044076412e-07
# Complementarity.........:   1.0025660199835991e-11    1.5038130318072414e-10
# Overall NLP error.......:   7.0656706146803619e-07    4.5396533962842655e-05
#
#
# Number of objective function evaluations             = 260
# Number of objective gradient evaluations             = 133
# Number of equality constraint evaluations            = 260
# Number of inequality constraint evaluations          = 260
# Number of equality constraint Jacobian evaluations   = 134
# Number of inequality constraint Jacobian evaluations = 134
# Number of Lagrangian Hessian evaluations             = 0
# Total seconds in IPOPT                               = 21.544
#
# EXIT: Optimal Solution Found.
